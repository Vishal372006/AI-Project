# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishal372006/AI-Project/blob/main/Vishal%20patel(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Healthcare_Data(3).csv")

# %%
data.head(30)
# Out:
#     Rural Area  Total Dr distributed  Total Dr available  \
# 0          NaN                   NaN                 NaN
# 1       Tenpur                 100.0                76.0
# 2       Rajpur                  87.0                67.0
# 3        Paldi                  65.0                59.0
# 4     Ambareli                  98.0                87.0
# 5      Khanpur                  76.0                65.0
# 6        Dholi                  54.0                40.0
# 7      Butvada                  46.0                32.0
# 8   Ranjitgadh                  60.0                54.0
# 9      Dhanala                  65.0                40.0
# 10      Shiroi                  76.0                65.0
# 11       Koyba                  63.0                51.0
# 12     Sukhpur                  87.0                69.0
# 13       Samli                  67.0                41.0
# 14     Palasan                  90.0                80.0
# ...

# %%
x_data = data["Gov beds distributed per 100,000 population"].head(20)
y_data = data["Gov beds availabe per 100,000 population"].head(20)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x_data,y_data)
plt.xlabel("Gov beds distributed per 100,000 population")
plt.ylabel("Gov beds availabe per 100,000 population")
plt.title("Gov beds distributed per 100,000 population vs Gov beds availabe per 100,000 population")
plt.show()
